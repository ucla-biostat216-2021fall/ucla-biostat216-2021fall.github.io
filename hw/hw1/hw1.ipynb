# %% [markdown]
# # Biostat 216 Homework 1
#
# **Due Sep 31 @ 11:59pm**

# %% [markdown]
# Submit a PDF to CCLE.
#
# BV exercises: 3.3, 3.4, 3.5, 3.12, 3.13, 3.15, 3.18, 3.27, 3.28, 5.1, 5.2, 5.4, and 5.6.
